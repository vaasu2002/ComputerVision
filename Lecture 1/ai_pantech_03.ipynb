# %%
import cv2
import imutils
import matplotlib.pyplot as plt

# %%
img = cv2.imread("Desktop/eng_analytical.PNG")
plt.imshow(img)

# %%
resize_img = imutils.resize(img,width=20) # resizing image
cv2.imwrite("resize_img.jpg",resize_img) # saving image

# %% [markdown]
# ## Smoothing Image

# %%
import cv2
img = cv2.imread("Desktop/istockphoto-1226241649-170667a.jpg")
gaussianBlurImg = cv2.GaussianBlur(img,(21,21),0)
cv2.imwrite("gaussianImage.jpg",gaussianBlurImg)
# Out:
# True

# %% [markdown]
# ## Color image to binary image

# %%
import cv2
img = cv2.imread("Desktop/istockphoto-1226241649-170667a.jpg")
grayImg = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
thresImg = cv2.threshold(grayImg,180,255,cv2.THRESH_BINARY) [1]
cv2.imwrite("thresholdImage2.jpg",thresImg)
# Out:
# True
